# %%
from client import Client
from model import Resource, Dataset
from IPython.display import display

stelar = Client("https://klms.stelar.gr/stelar", username="admin", password="stelartuc", version="v2")


dset = stelar.catalog.get_dataset("dimitris")
display(dset)


rsrc = Resource("s3://klms-bucket/test_path/obj.txt","TXT","A test resource published from the Client")
stelar.catalog.publish_dataset_resource(dset, rsrc)


display(dset)
# Out:
#         <strong>Dataset Summary:</strong>
#         <table>
#             <tr><th>Attribute</th><th>Value</th></tr>
#             <tr><td>ID</td><td>2a161060-aa29-4f4a-8312-47dbd9119c7c</td></tr>
#             <tr><td>Title</td><td>Test Data API 1</td></tr>
#             <tr><td>Notes</td><td>This dataset contains Points of Interest extracted from OpenStreetMap</td></tr>
#             <tr><td>Tags</td><td>Bavaria, STELAR</td></tr>
#             <tr><td>Modified Date</td><td>2024-11-28T17:05:46.776572</td></tr>
#         </table>
#         <br>
#         <strong>Dataset Resources:</strong>
#         <table border="1" style="border-collapse: collapse; width: 100%;">
#             <tr><th>ID</th><th>Name</th><th>URL</th><th>Format</th></tr>
#
#                 <tr>
#                     <td>e40325c7-93b2-48d2-82ef-bcbd14c57697</td>
#                     <td>New Resource</td>
#                     <td><a href="s3://klms-bucket/j" target="_blank">s3://klms-bucket/j</a></td>
#                     <td>TXT</td>
#                 </tr>
#
#                 <tr>
#                     <td>88d67200-f518-4458-a6c3-fc4f2b38bb2b</td>
#                     <td>None</td>
#                     <td><a href="" target="_blank"></a></td>
#                     <td></td>
#                 </tr>
#
#                 <tr>
#                     <td>fc741675-aeb4-4a98-810e-ab2bf1ba522d</td>
#                     <td>JBJHBHJ</td>
#                     <td><a href="http://GUGYUGU" target="_blank">http://GUGYUGU</a></td>
#                     <td></td>
#                 </tr>
#
#                 <tr>
#                     <td>f12f88cf-3789-4d05-b5b4-03d860fd0422</td>
#                     <td>LAI profile in JSON</td>
#                     <td><a href="s3://klms-bucket/j" target="_blank">s3://klms-bucket/j</a></td>
#                     <td>JSON</td>
#                 </tr>
#
#                 <tr>
#                     <td>4185428a-e46d-4388-9f52-3e6b765f0734</td>
#                     <td>New Resource</td>
#                     <td><a href="s3://klms-bucket" target="_blank">s3://klms-bucket</a></td>
#                     <td>TXT</td>
#                 </tr>
#
#                 <tr>
#                     <td>9d912de9-7725-451d-9416-68fe4c061785</td>
#                     <td>New Resource 2</td>
#                     <td><a href="s3://klms-bucket" target="_blank">s3://klms-bucket</a></td>
#                     <td>TXT</td>
#                 </tr>
#
#         </table>
#         <strong>Dataset Summary:</strong>
#         <table>
#             <tr><th>Attribute</th><th>Value</th></tr>
#             <tr><td>ID</td><td>2a161060-aa29-4f4a-8312-47dbd9119c7c</td></tr>
#             <tr><td>Title</td><td>Test Data API 1</td></tr>
#             <tr><td>Notes</td><td>This dataset contains Points of Interest extracted from OpenStreetMap</td></tr>
#             <tr><td>Tags</td><td>Bavaria, STELAR</td></tr>
#             <tr><td>Modified Date</td><td>2024-11-28T17:05:46.776572</td></tr>
#         </table>
#         <br>
#         <strong>Dataset Resources:</strong>
#         <table border="1" style="border-collapse: collapse; width: 100%;">
#             <tr><th>ID</th><th>Name</th><th>URL</th><th>Format</th></tr>
#
#                 <tr>
#                     <td>e40325c7-93b2-48d2-82ef-bcbd14c57697</td>
#                     <td>New Resource</td>
#                     <td><a href="s3://klms-bucket/j" target="_blank">s3://klms-bucket/j</a></td>
#                     <td>TXT</td>
#                 </tr>
#
#                 <tr>
#                     <td>88d67200-f518-4458-a6c3-fc4f2b38bb2b</td>
#                     <td>None</td>
#                     <td><a href="" target="_blank"></a></td>
#                     <td></td>
#                 </tr>
#
#                 <tr>
#                     <td>fc741675-aeb4-4a98-810e-ab2bf1ba522d</td>
#                     <td>JBJHBHJ</td>
#                     <td><a href="http://GUGYUGU" target="_blank">http://GUGYUGU</a></td>
#                     <td></td>
#                 </tr>
#
#                 <tr>
#                     <td>f12f88cf-3789-4d05-b5b4-03d860fd0422</td>
#                     <td>LAI profile in JSON</td>
#                     <td><a href="s3://klms-bucket/j" target="_blank">s3://klms-bucket/j</a></td>
#                     <td>JSON</td>
#                 </tr>
#
#                 <tr>
#                     <td>4185428a-e46d-4388-9f52-3e6b765f0734</td>
#                     <td>New Resource</td>
#                     <td><a href="s3://klms-bucket" target="_blank">s3://klms-bucket</a></td>
#                     <td>TXT</td>
#                 </tr>
#
#                 <tr>
#                     <td>9d912de9-7725-451d-9416-68fe4c061785</td>
#                     <td>New Resource 2</td>
#                     <td><a href="s3://klms-bucket" target="_blank">s3://klms-bucket</a></td>
#                     <td>TXT</td>
#                 </tr>
#
#                 <tr>
#                     <td>1b165496-8b42-4d04-ad8f-8988431fa52c</td>
#                     <td>A test resource published from the Client</td>
#                     <td><a href="s3://klms-bucket/test_path/obj.txt" target="_blank">s3://klms-bucket/test_path/obj.txt</a></td>
#                     <td>TXT</td>
#                 </tr>
#
#         </table>
